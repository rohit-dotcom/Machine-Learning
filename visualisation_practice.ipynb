# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
dataPath="./Data/all-census-data-india_districts/gdp_Odisha1.csv"

# %%
df=pd.read_csv('./Data/all-census-data-india_districts/gdp_Odisha1.csv')
df2=pd.read_csv('./Data/all-census-data-india_districts/gdp_Odisha1.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            15 non-null     object
#  1   Description     15 non-null     object
#  2    Angul          15 non-null     float64
#  3   Balangir        15 non-null     float64
#  4    Balasore       15 non-null     float64
#  5   Bargarh         15 non-null     float64
#  6   Baudh           15 non-null     float64
#  7   Bhadrak         15 non-null     float64
#  8   Cuttack         15 non-null     float64
#  9    Deogarh        15 non-null     float64
#  10  Dhenkanal       15 non-null     float64
#  11  Gajapati        15 non-null     float64
#  12  Ganjam          15 non-null     float64
#  13   Jagatsinghpur  15 non-null     float64
#  14   Jajpur         15 non-null     float64
#  15  Jharsuguda      15 non-null     float64
#  16  Kalahandi       15 non-null     float64
# ...

# %%
df2[['Year']].max(),df2[['Year']].min()
# Out:
# (Year    2006-07
#  dtype: object,
#  Year    1999-00
#  dtype: object)

# %%
df=df2.set_index('Year',inplace=True)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
ax=plt.gca()

df2.plot(kind='bar',x='Year',y=['Kalahandi'],sharey=True)
df2.plot(kind='bar',x='Year',y='Khordha',color='red',sharey=True,subplots=True,alpha=.5)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002280342EF48>],
#       dtype=object)

# %%
df3=pd.read_csv('./Data/all-census-data-india_districts/elementary_2015_16.csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Columns: 800 entries, Unnamed: 0 to (TOTCLS7G)
# dtypes: float64(13), int64(784), object(3)
# memory usage: 4.2+ MB

# %%
data_odisha=df3[df3['STATE NAME']=='ODISHA']

# %%
data_odisha.plot(kind='bar',x='DISTRICT NAME',y='TOTAL POULATION',figsize=(20,5))

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'YEAR', 'STATE NAME', 'DISTRICT NAME', 'TOTAL POULATION',
#        'PERCENTAGE URBAN POPULATION', '0-6 POPULATION', 'GROWTH RATE',
#        'SEX RATIO', 'PERCENTAGE SC POPULATION',
#        ...
#        'ALL  (UUNI ALL)', 'SC (UUNI SC)', 'ST (UUNI ST)', '(TOTCLS1G)',
#        '(TOTCLS2G)', '(TOTCLS3G)', '(TOTCLS4G)', '(TOTCLS5G)', '(TOTCLS6G)',
#        '(TOTCLS7G)'],
#       dtype='object', length=800)

# %%
df4=pd.read_csv('./Data/all-census-data-india_districts/india-districts-census-2011.csv')
data=df4.groupby('State Name')

# %%
data.first()
# Out:
#                              District code           District name  \
# State Name
# ANDAMAN AND NICOBAR ISLANDS            638                Nicobars
# ANDHRA PRADESH                         532                Adilabad
# ARUNACHAL PRADESH                      245                  Tawang
# ASSAM                                  300               Kokrajhar
# BIHAR                                  203      Pashchim Champaran
# CHANDIGARH                              55              Chandigarh
# CHHATTISGARH                           400                  Koriya
# DADRA AND NAGAR HAVELI                 496  Dadra AND Nagar Haveli
# DAMAN AND DIU                          494                     Diu
# GOA                                    585               North Goa
# GUJARAT                                468                 Kachchh
# HARYANA                                 69               Panchkula
# HIMACHAL PRADESH                        23                  Chamba
# ...
